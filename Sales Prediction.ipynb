# %% [markdown]
# ![Oasis%20Infobyte-2.jpg](attachment:Oasis%20Infobyte-2.jpg)

# %% [markdown]
# # _Oasis Infobyte Internship_
#
# ### _Task 1 - Sales Prediction using Python Machine learning_
#
# _Code Author - Manoj Kumar_
#
# _Data Science Virtual Internship Program_

# %% [markdown]
# ## _Import Modules_

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv("E:\Mano@workspace\Datasets\Advertising.csv")

# %%
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %% [markdown]
# ## _Data Cleaning & Analysis_

# %%
data=data.drop(labels=["Unnamed: 0"],axis=1)
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
data.shape
# Out:
# (200, 4)

# %%
data.isnull()
# Out:
#         TV  Radio  Newspaper  Sales
# 0    False  False      False  False
# 1    False  False      False  False
# 2    False  False      False  False
# 3    False  False      False  False
# 4    False  False      False  False
# ..     ...    ...        ...    ...
# 195  False  False      False  False
# 196  False  False      False  False
# 197  False  False      False  False
# 198  False  False      False  False
# 199  False  False      False  False
#
# [200 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
x=data.iloc[:, 0:-1]
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=data.iloc[:,-1]
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %% [markdown]
# ## _Visualize_

# %%
plt.plot(x,y,ls='',marker='o')
plt.xlabel('Adverstising')
plt.ylabel('Sales')
plt.legend(['TV','Radio','Newspaper'])
plt.title('Sales Percentage')
# Out:
# Text(0.5, 1.0, 'Sales Percentage')

# %% [markdown]
# ## _Train the Data_

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=40)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 188  286.0   13.9        3.7
# 170   50.0   11.6       18.4
# 107   90.4    0.3       23.2
# 65    69.0    9.3        0.9
# 109  255.4   26.9        5.5
# ..     ...    ...        ...
# 50   199.8    3.1       34.6
# 184  253.8   21.3       30.0
# 165  234.5    3.4       84.8
# 7    120.2   19.6       11.6
# 70   199.1   30.6       38.7
#
# [140 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 96   197.6    3.5        5.9
# 5      8.7   48.9       75.0
# 116  139.2   14.3       25.6
# 35   290.7    4.1        8.5
# 183  287.6   43.0       71.8
# 160  172.5   18.1       30.7
# 54   262.7   28.8       15.9
# 134   36.9   38.6       65.6
# 90   134.3    4.9        9.3
# 191   75.5   10.8        6.0
# 139  184.9   43.9        1.7
# 142  220.5   33.2       37.9
# 177  170.2    7.8       35.2
# 26   142.9   29.3       12.6
# 89   109.8   47.8       51.4
# 140   73.4   17.0       12.9
# 171  164.5   20.9       47.4
# 23   228.3   16.9       26.2
# 132    8.4   27.2        2.1
# 37    74.7   49.4       45.7
# 151  121.0    8.4       48.7
# 28   248.8   27.1       22.9
# 85   193.2   18.4       65.7
# 93   250.9   36.5       72.3
# 174  222.4    3.4       13.1
# 75    16.9   43.7       89.4
# 18    69.2   20.5       18.3
# 105  137.9   46.4       59.0
# 121   18.8   21.7       50.4
# 130    0.7   39.6        8.7
# 33   265.6   20.0        0.3
# ...

# %%
y_train
# Out:
# 188    15.9
# 170     8.4
# 107     8.7
# 65      9.3
# 109    19.8
#        ...
# 50     11.4
# 184    17.6
# 165    11.9
# 7      13.2
# 70     18.3
# Name: Sales, Length: 140, dtype: float64

# %%
y_test
# Out:
# 96     11.7
# 5       7.2
# 116    12.2
# 35     12.8
# 183    26.2
# 160    14.4
# 54     20.2
# 134    10.8
# 90     11.2
# 191     9.9
# 139    20.7
# 142    20.1
# 177    11.7
# 26     15.0
# 89     16.7
# 140    10.9
# 171    14.5
# 23     15.5
# 132     5.7
# 37     14.7
# 151    11.6
# 28     18.9
# 85     15.2
# 93     22.2
# 174    11.5
# 75      8.7
# 18     11.3
# 105    19.2
# 121     7.0
# 130     1.6
# 33     17.4
# 46     10.6
# 168    17.1
# 169    15.0
# 11     17.4
# 166     8.0
# 81     12.3
# 111    21.8
# 67     13.4
# 147    25.4
# 86     12.0
# 182     8.7
# 69     22.3
# 125    10.6
# 42     20.7
# 77     14.2
# 62     15.7
# 154    15.6
# 59     18.4
# 148    10.9
# 175    27.0
# 24      9.7
# 143    10.4
# 64     18.0
# 196     9.7
# 40     16.6
# 112    14.1
# 52     22.6
# 145    10.3
# 136     9.5
# Name: Sales, dtype: float64

# %%
x_train=x_train.astype(int)
y_train=y_train.astype(int)
x_test=x_test.astype(int)
y_test=y_test.astype(int)

# %%
from sklearn.preprocessing import StandardScaler
Sc=StandardScaler()
x_train_scaled=Sc.fit_transform(x_train)
x_test_scaled=Sc.fit_transform(x_test)

# %% [markdown]
# ## _Linear Regression_

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test_scaled)

# %%
y_pred
# Out:
# array([11.08547112, 11.61425386, 10.68528983, 15.3290509 , 22.78842102,
#        12.91050521, 18.94153265, 10.85769579,  8.52022647,  7.1797817 ,
#        18.65485765, 18.01154015, 10.56579834, 13.92618265, 15.93927434,
#         8.48209261, 12.8802965 , 14.96755885,  7.7274163 , 14.84933555,
#         8.56503346, 18.09218496, 13.64707608, 19.74932241, 12.13482226,
#        10.87695322,  8.88558969, 16.91656917,  6.70025709,  9.78252999,
#        17.52604729,  7.43890076, 15.6620416 , 16.2949968 , 16.09285444,
#        10.05156394, 12.96131437, 20.01363141, 10.76213782, 22.22513508,
#        10.62140742,  5.21880858, 19.91728548,  7.80869926, 20.16237828,
#        12.7535432 , 15.23928709, 14.2809846 , 16.90726816, 11.62736895,
#        23.47685245,  6.95712164,  7.28663912, 16.00212066,  6.78081089,
#        15.02537297, 12.57610504, 19.45001364,  8.17321712, 10.86774353])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8277019090764448

# %% [markdown]
# ## _Analyse Predicted Sales Data_

# %%
plt.scatter(y_test,y_pred,c='g')

# %% [markdown]
# ## _Summary_
#
# _Sales Prediction using Advertising data is cleaned and analyse then craeting a machine learning prediction model to predict the sales value by advertising data._
